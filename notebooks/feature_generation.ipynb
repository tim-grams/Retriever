# %% [markdown]
# # Feature Generation

# %% [markdown]
# ### Imports

# %%
import os
import sys
sys.path.append(os.path.dirname((os.path.abspath(""))))

# %%
from src.pipeline import Pipeline
# Out:
# [nltk_data] Downloading package punkt to /Users/tim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/tim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/tim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/tim/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
pipeline = Pipeline()

# %% [markdown]
# ### Configuration

# %%
pipeline.setup(qrel_sampling=30, training_sampling=5000, irrelevant_sampling=1000)

# %% [markdown]
# ### Preprocessing and Feature Generation

# %%
pipeline.preprocess()
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 600.46it/s]

# %%
pipeline.create_train_features()
# Out:
# /Users/tim/opt/anaconda3/envs/inforetrieval/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9977/9977 [00:09<00:00, 1038.44it/s]

# %%
pipeline.features
# Out:
#           qID      pID  y  w2v_cosine  w2v_euclidean  w2v_manhattan  \
# 0      603195  7050012  1    0.972107     144.641830    1124.871630
# 1      474183   325505  1    0.971866     131.960266    1033.670312
# 2      320545  1751825  1    0.947701      94.900002     756.378183
# 3       89798  5069949  1    0.972710     161.470459    1273.643564
# 4     1054603  2869106  1    0.965680     155.648453    1216.564726
# ...       ...      ... ..         ...            ...            ...
# 4995   128401  6127598  0    0.796978      85.670822     678.466760
# 4996  1044540  4616118  0    0.922095     157.044754    1238.354322
# 4997   486146  1137390  0    0.946438     125.126984     972.330644
# 4998   532697  5161847  0    0.938939      99.808395     790.453814
# 4999   763472  6447198  0    0.988622     134.510406    1094.769867
#
#       w2v_tfidf_cosine  w2v_tfidf_euclidean  w2v_tfidf_manhattan  \
# 0             0.938781             2.765727            22.236694
# ...

# %%
pipeline.create_val_features()
# Out:
# /Users/tim/opt/anaconda3/envs/inforetrieval/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 451680/451680 [06:36<00:00, 1138.58it/s]

# %%
pipeline.features_val
# Out:
#            qID      pID  w2v_cosine  w2v_euclidean  w2v_manhattan  \
# 0       156493   945864    0.792954      71.107925     573.999957
# 1       156493  2776470    0.729307      85.190117     689.481108
# 2       156493  1897608    0.705428     157.311096    1274.077898
# 3       156493  2707038    0.553514      73.165138     569.408292
# 4       156493  5712720    0.759587     280.687256    2192.774160
# ...        ...      ...         ...            ...            ...
# 15051  1129237  8837917    0.807216     106.185928     837.061440
# 15052  1129237  8838111    0.605659     173.478958    1437.293269
# 15053  1129237  8839919    0.724433     114.784401     910.546293
# 15054  1129237  8839920    0.800587     144.010162    1131.883229
# 15055  1129237  8839922    0.849563     139.465195    1093.148819
#
#        w2v_tfidf_cosine  w2v_tfidf_euclidean  w2v_tfidf_manhattan  \
# 0              0.571350            10.852615            85.193131
# ...

# %%
pipeline.create_test_features()
# Out:
# /Users/tim/opt/anaconda3/envs/inforetrieval/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 451680/451680 [06:49<00:00, 1101.67it/s]

# %%
pipeline.features_test
# Out:
#            qID      pID  w2v_cosine  w2v_euclidean  w2v_manhattan  \
# 0      1037496   945864    0.753261      79.298035     645.454931
# 1      1037496  2776470    0.725403      93.541176     747.352264
# 2      1037496  1897608    0.904503     164.880341    1341.113300
# 3      1037496  2707038    0.955766      75.539719     591.411043
# 4      1037496  5712720    0.616049     288.198853    2239.713961
# ...        ...      ...         ...            ...            ...
# 15051   997622  8837917    0.672739     115.023979     894.910870
# 15052   997622  8838111    0.707098     175.582809    1452.498573
# 15053   997622  8839919    0.941848     117.086525     926.588398
# 15054   997622  8839920    0.898124     148.882675    1180.330558
# 15055   997622  8839922    0.856419     146.015137    1168.976624
#
#        w2v_tfidf_cosine  w2v_tfidf_euclidean  w2v_tfidf_manhattan  \
# 0              0.375286             4.089369            31.686272
# ...

# %% [markdown]
# ### Save

# %%
pipeline.save('30_5000_1000')
